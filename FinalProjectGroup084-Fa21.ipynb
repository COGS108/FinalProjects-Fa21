# %% [markdown]
# # NBA Shooting Patterns Over The Past 20 Years

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [X] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# In this project we investigate the trends of NBA players' shooting patterns over time. Using data from 20 seasons beginning in 2000 to 2020, we analyzed where players were taking more shots from and where they were taking less shots. By doing so we observed that there has a been significant increase in three point attempts and decrease in two point attenmpts. In addition, we also analyzed how the players' positions have changed over time and how they may be affected by the changing shooting patterns. This revealed that all player positions have increased their three point attempts but the physically bigger players, in particular, have had a greater increase.

# %% [markdown]
# # Names
#
# - James Lu
# - Jorge Acevedo
# - Rahil Shah
# - Alan Amirian
# - Matin Ghaffari

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# How have players' two point and three point shooting patterns changed over the last 20 years from October 29, 2000 to October 11, 2020 and how has these changes affected various player positions?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# &emsp;&emsp; Our group decided to conduct our research question on a popular topic in the NBA community, shooting trends in the NBA. More specifically, we decided to look at patterns where players took more or less shots than before, and variations in the positions of those players. We are interested in answering such a question to provide more insight to spectators and followers in the dynamics of the game that aren't easily observable at glance but rather in trends that can be found in data with abundant observations over time. By answering this question we can help those who analyze the sport to provide a better understanding of the game and team dynamics and to potentially help those who study, report, or wage on the sport through our analysis.
#
# &emsp;&emsp; It is by no means a secret that there are more three point shots being shot than ever before (source 5). We were curious about who is shooting these three pointers by examining their positions and other various shooting statistics to determine whether or not they were effective in their job. According to Fivethirtyeight (source 6), "NBA players make only 40 percent of their shots between 8 and 9 feet from the rim, and that number drops to only 35 percent between 25 and 26 feet from the rim”. For context, the three point shot line varies from 22 feet at the corners to 23 feet and 9 inches at its furthest point (source 7). This small difference in risk between a 2 point shot and 3 point shot potentially makes it more advantageous to shoot a 3 rather than a 2 pointer and likely explains why NBA players might be taking more three point shots than ever before.
#
# &emsp;&emsp; In addition to analyzing the number of three point attempts we also wanted to explore how positions have been impacted by potentially increasing three point attempts. We expect that with the change in floor spacing, the roles of traditional big men and center positions might also change (source 8). To provide better context The Guardian (source 8) uses Dirk Nowitzki as an example of a player breaking the traditional mold for his position and compares how other players with the same archetype are playing that role today. Some may attribute the increase in 3-point shot attempts to stronger defense in the 2-point zone, but it could also be related to the increase in skill of 3-point shooters. Thus, we would like to weigh the value of defense and increased shooting skill through various differen't defensive and shooting statistics to address this concern in our project.
#
# References (include links):
# - 1) https://www.basketball-reference.com/
# - 2) https://www.nba.com/
# - 3) https://datavizardry.com/
# - 4) https://towardsdatascience.com/are-3-pointers-more-important-than-2-pointers-in-the-nba-1fa8e1422c60
# - 5) https://www.theringer.com/nba/2019/2/27/18240583/3-point-boom-
# - 6) https://fivethirtyeight.com/features/how-mapping-shots-in-the-nba-changed-it-forever/
# - 7) https://basketballword.com/how-far-is-the-3-point-line-from-the-hoop/
# - 8) https://www.theguardian.com/sport/blog/2018/may/01/how-and-why-position-less-lineups-have-taken-over-the-nba-playoffs

# %% [markdown]
# # Hypothesis

# %% [markdown]
# &emsp;&emsp; We hypothesize that more three point shots are being taken than ever before and that there is a larger diversity of positions who are shooting three point shots than ever before. We hypothesize this because this is a common trend being observed by many and being discussed in statistics, we see this according to Fivethirtyeight (source 6), "NBA players make only 40 percent of their shots between 8 and 9 feet from the rim, and that number drops to only 35 percent between 25 and 26 feet from the rim”. Since the three point shot line varies from 22 feet at the corners to 23 feet and 9 inches at its furthest point we know that this range falls near the range where 40 percent of players make their shot which is only a 5% difference in chance from a two pointer (source 7). This small difference in risk between a 2 point shot and 3 point shot makes it more advantageous to shoot a 3 point shot rather than a 2 point shot which provides valuable reasoning to support our hypothesis and potentially explains why NBA players might be taking more three point shots than ever before.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: 2019-20 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2020_totals.html
# - Number of observations: 651
#
# This dataset contains statistics and information on all players who participated in the 2019-2020 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2018-19 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2019_totals.html
# - Number of observations: 708
#
# This dataset contains statistics and information on all players who participated in the 2018-2019 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2017-18 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2018_totals.html
# - Number of observations: 664
#
# This dataset contains statistics and information on all players who participated in the 2017-2018 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2016-17 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2017_totals.html
# - Number of observations: 595
#
# This dataset contains statistics and information on all players who participated in the 2016-2017 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2015-16 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2016_totals.html
# - Number of observations: 578
#
# This dataset contains statistics and information on all players who participated in the 2015-2016 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2014-15 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2015_totals.html
# - Number of observations: 651
#
# This dataset contains statistics and information on all players who participated in the 2014-2015 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2013-14 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2014_totals.html
# - Number of observations: 611
#
# This dataset contains statistics and information on all players who participated in the 2013-2014 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2012-13 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2013_totals.html
# - Number of observations: 573
#
# This dataset contains statistics and information on all players who participated in the 2012-2013 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2011-12 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2012_totals.html
# - Number of observations: 551
#
# This dataset contains statistics and information on all players who participated in the 2011-2012 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2010-11 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2011_totals.html
# - Number of observations: 625
#
# This dataset contains statistics and information on all players who participated in the 2010-2011 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2009-10 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2010_totals.html
# - Number of observations: 578
#
# This dataset contains statistics and information on all players who participated in the 2009-2010 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2008-09 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2009_totals.html
# - Number of observations: 582
#
# This dataset contains statistics and information on all players who participated in the 2008-2009 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2007-08 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2008_totals.html
# - Number of observations: 595
#
# This dataset contains statistics and information on all players who participated in the 2007-2008 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2006-07 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2007_totals.html
# - Number of observations: 516
#
# This dataset contains statistics and information on all players who participated in the 2006-2007 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2005-06 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2006_totals.html
# - Number of observations: 563
#
# This dataset contains statistics and information on all players who participated in the 2005-2006 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2004-05 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2005_totals.html
# - Number of observations: 585
#
# This dataset contains statistics and information on all players who participated in the 2004-2005 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2003-04 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2004_totals.html
# - Number of observations: 585
#
# This dataset contains statistics and information on all players who participated in the 2003-2004 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2002-03 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2003_totals.html
# - Number of observations: 483
#
# This dataset contains statistics and information on all players who participated in the 2002-2003 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2001-02 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2002_totals.html
# - Number of observations: 500
#
# This dataset contains statistics and information on all players who participated in the 2001-2002 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
# - Dataset Name: 2000-01 NBA Player Stats: Totals
# - Link to the dataset: https://www.basketball-reference.com/leagues/NBA_2001_totals.html
# - Number of observations: 537
#
# This dataset contains statistics and information on all players who participated in the 2000-2001 NBA season and this source provides official NBA data as provided by SportRadar, which is the official statistics provider of the NBA. The columns of emphasis include quantatative measures regarding 2 and 3 point makes (discrete), attempts (discrete), and percentages (continuous), number of games (discrete), minutes played (discrete), as well as nominal categorical variables of player name, team, and position.
#
#
# Since our multiple datasets will have the same columns, and sometimes even the same unique identifiers (players who played in multiple seasons), we are easily able to concatenate or merge the datasets together or compare changes between the datasets. Furthermore the correspondence in details of the our datasets also allows us to set our index as the players' unique identifier to make our data relational, and also gives us the ability to create a singular methods that can process all these datasets like we do for our cleaning.

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display # used to print a series of dataframes in nice formatting
import os                           # used for handling filepaths
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import patsy
from sklearn.model_selection import train_test_split
import sklearn
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from scipy import stats



# Our data source had no way to export the csv, however they did have the csv formats available and we just
# had to copy and paste the data into our own files, which are found in the data subdirectory of our repository

# List of file paths for NBA statistics from 2000-2020 are iterated through in the data cleaning 
# section where they are passed into a method that reads the .csv files and cleans the 'data' 
# while also saving the cleaned data to new .csv files in the 'cleanedData' subdirectory
filepaths = ["cleanedData/2019_2020statsNBA_clean.csv", "cleanedData/2018_2019statsNBA_clean.csv", "cleanedData/2017_2018statsNBA_clean.csv",
             "cleanedData/2016_2017statsNBA_clean.csv", "cleanedData/2015_2016statsNBA_clean.csv", "cleanedData/2014_2015statsNBA_clean.csv",
             "cleanedData/2013_2014statsNBA_clean.csv", "cleanedData/2012_2013statsNBA_clean.csv", "cleanedData/2011_2012statsNBA_clean.csv",
             "cleanedData/2010_2011statsNBA_clean.csv", "cleanedData/2009_2010statsNBA_clean.csv", "cleanedData/2008_2009statsNBA_clean.csv",
             "cleanedData/2007_2008statsNBA_clean.csv", "cleanedData/2006_2007statsNBA_clean.csv", "cleanedData/2005_2006statsNBA_clean.csv",
             "cleanedData/2004_2005statsNBA_clean.csv", "cleanedData/2003_2004statsNBA_clean.csv", "cleanedData/2002_2003statsNBA_clean.csv",
             "cleanedData/2001_2002statsNBA_clean.csv", "cleanedData/2000_2001statsNBA_clean.csv"]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# First we took a look at the datasets before any processing by printing and looking at the data itself, observing its shape and the number of null/non-null entries in each of the variables via the .info() method (done in the 2nd for loop in the code below). By doing so we only saw non-null data in the float64 columns for percentage variables like as FG% (Field Goal %), 3P% (3 point %), 2P% (2 point %) which makes sense since there are division by zero erorrs when no field goals of a certain category are attempted, thus it makes sense that these are already set as NaN values. After doing this we see that our datasets have no missingness that we need to account for.
#
# After doing our initial observations we constructed a method (clean_NBAstats) that accepts a filepath as an argument in order to  clean all 20 of our datasets with a for loop that is responsible for passing each dataset filepath into this clean method. First the method reads the dataframe from the csv file path and reads the data only with the columns that we care about which are 'Player', 'Pos', 'Tm', 'G', 'MP', '3P', '3PA', '3P%', '2P', '2PA', '2P%'. These columns  include quantatative measures regarding 2 and 3 point makes ('2P' & '3P') (discrete), attempts ('2PA' & '3PA') (discrete), and percentages ('2P%' & '3P%') (continuous), number of games ('G') (discrete), minutes played ('MP') (discrete), as well as nominal categorical variables of team ('Tm'), position ('Pos'), and player name (Player).
#
# Then our method cleans the 'Player' column by using the str.split method to seperate the players' unique identifiers from their first and last name into 2 seperate columns, where the first and last name remain in the 'Player' column while the unique identifier is assigned to the 'PlayerID' column which is then ultimately set as the index of the datasets.
#
# Next our method needed to clean duplicate player names which occurs in the case when players played for multiple teams in a given season. We handle these cases by and keeping their combined statistics and dropping their redundant partial observations. Additionaly, our method cleans the untidy data in the 'Pos' column since some players have both a primary and secondary position denoted by PrimaryPos-SecondaryPos. Since we only care about a player's primary position, for these cases we just keep the primary position in our observations.
#
# Finally, we ran the .info() method again on all the cleaned datasets to ensure that we have accounted for all potential missing data and found that our cleaning was succesful and that our cleaned data is tidy. Then our method writes the newly cleaned data as a new csv with "_clean" appended to the end of the file name and saves the new csv files in the "cleanedData" subdirectory of our repository.

# %%
# Method accepts file paths for NBA statistics from 2000-2020 to clean the data
def clean_NBAstats(fp):
    # Read each year of NBA stats data from the file path of the csv files for statistics from 2000-2020
    # and we only read the data with the columns that we care about 
    df = pd.read_csv(fp, usecols=['Player','Pos', 'Tm','G','MP','3P','3PA','3P%','2P','2PA','2P%'])
    
    # Clean the player names by using str.split method to seperate the players' unique identifiers from
    # their first and last name into 2 seperate columns 
    # e.g: Player: Jaylen Adams\adamsja01 --> Player: Jaylen Adams, PlayerID: adamsja01
    df[['Player','PlayerID']] = df.Player.str.split("\\",expand=True) 
    
    # If a player appears in multiple observations/teams this means that the player was traded mid-season
    # and in these cases we take the total statistics from all their observations and use an aggregated 
    # total observation for these players and dropping the duplicate observations
    mask = (df.groupby('Player').size() > 1)
    dupes = df[df['Player'].isin(mask[mask].index)]
    df = df.drop(dupes[~(dupes['Tm'] == 'TOT')].index).reset_index(drop=True)
    
    # Some players have both a primary and secondary position denoted by PrimaryPos-SecondaryPos in these cases
    # we only care about a player's primary position so we just keep the primary position in our observations
    df['Pos'] = df['Pos'].str.replace('-.*', '', regex=True)
    
    # Setting the index as the unique identifier of each player
    df = df.set_index('PlayerID')
    
    # We ran .info() on each dataframe to ensure we are accounting for any missing data
    # df.info()
    # We only saw non-null data in the float64 columns for 3P% (3 point %) and 2P% (2 point %)
    # which makes sense since there are division by zero erorrs when no field goals of a certain category are 
    # attempted thus it makes sense that these are set as NaN values. Thus accounting for any possible missingness

    # Using os to get the base of the file path and the extension, which we
    # use for writing our clean data as .csv with a new name and subdirectory
    base = os.path.basename(fp)
    fp_base = os.path.splitext(base)[0]
    fp_ext = os.path.splitext(base)[1]
    
    # Writing the cleaned data frames as .csv in the cleanedData/ subdirectory of our repository
    df.to_csv("cleanedData/" + fp_base + "_clean" + fp_ext)
    
    return df

# list of all frames for each respective dataset
frames = []

for fp in filepaths[::-1]:
    df = pd.read_csv(fp)
    frames.append(df)

# %% [markdown]
# # Data Analysis & Results

# %%
frames[0]
# Out:
#       PlayerID               Player Pos   Tm   G    MP   FGA  3P  3PA    3P%  \
# 0    abdulma02   Mahmoud Abdul-Rauf  PG  VAN  41   486   246   4   14  0.286
# 1    abdulta01    Tariq Abdul-Wahad  SG  DEN  29   420   111   4   10  0.400
# 2    abdursh01  Shareef Abdur-Rahim  SF  VAN  81  3241  1280  12   64  0.188
# 3    alexaco01       Cory Alexander  PG  ORL  26   227    56   4   16  0.250
# 4    alexaco02   Courtney Alexander  PG  TOT  65  1382   573  17   46  0.370
# ..         ...                  ...  ..  ...  ..   ...   ...  ..  ...    ...
# 436  wingada01        David Wingate  SG  SEA   1     9     3   0    0    NaN
# 437  wolkoru01     Rubén Wolkowyski  PF  SEA  34   305    79   0    2  0.000
# 438  artesro01    Metta World Peace  SF  CHI  76  2363   815  43  148  0.291
# 439  wrighlo02      Lorenzen Wright   C  ATL  71  1988   811   0    2  0.000
# 440  zhizhwa01          Wang Zhizhi   C  DAL   5    38    19   0    2  0.000
#
#       2P   2PA    2P%     Season
# ...

# %% [markdown]
# The table above is an example of what each season's dataframe looks like.

# %%
# Concatenating our dataframes so that we can have the data from each season into a single data frame
agg_df = pd.DataFrame()

for frame in frames:
    agg_df = agg_df.append(frame, ignore_index = True)

agg_df
# Out:
#        PlayerID               Player Pos   Tm   G    MP   FGA   3P  3PA  \
# 0     abdulma02   Mahmoud Abdul-Rauf  PG  VAN  41   486   246    4   14
# 1     abdulta01    Tariq Abdul-Wahad  SG  DEN  29   420   111    4   10
# 2     abdursh01  Shareef Abdur-Rahim  SF  VAN  81  3241  1280   12   64
# 3     alexaco01       Cory Alexander  PG  ORL  26   227    56    4   16
# 4     alexaco02   Courtney Alexander  PG  TOT  65  1382   573   17   46
# ...         ...                  ...  ..  ...  ..   ...   ...  ...  ...
# 9391  youngtr01           Trae Young  PG  ATL  60  2120  1249  205  568
# 9392  zelleco01          Cody Zeller   C  CHO  58  1341   479   18   75
# 9393  zellety01         Tyler Zeller   C  SAS   2     4     4    0    0
# 9394  zizican01           Ante Žižić   C  CLE  22   221    72    0    0
# 9395  zubaciv01          Ivica Zubac   C  LAC  72  1326   385    0    2
#
#         3P%   2P   2PA    2P%     Season
# 0     0.286  116   232  0.500  2000-2001
# ...

# %% [markdown]
# The table above is how our dataset looks after combining the data from each season.

# %%
r, c = 5, 4
fig, axes = plt.subplots(r, c, figsize=(25, 25))

seasons = [str(i) + '-' + str(i+1) for i in range(2000, 2020)]

i = 0
for x in range(r):
    for y in range(c):
        sns.countplot(ax=axes[x, y], x='Pos', data=frames[i], order=['PG', 'SG', 'SF', 'PF', 'C'])
        axes[x, y].set_title(f'Potistional Distributions for {seasons[i]} Season')
        i += 1
        
plt.show()

# %% [markdown]
# This bar plot displays the count of players at each position throughout each season. Positional distribution doesn't seem to change in any predictable or meaningful way throughout the seasons, the differences in counts from season to season can be attributed to variance in players entering and exiting the NBA.

# %%
pivot = agg_df.pivot_table(index = 'Pos', columns ='Season' ,
                       aggfunc = 'count', values = 'Tm').fillna(0)

g = sns.catplot(x='Pos', hue="Season", 
          data=agg_df, palette='tab20',
            kind="count", height=7, aspect=3, orient = "h", legend = True, legend_out = True);

plt.suptitle("Positional Distributions for Each Season (2000-2020)", y =1.05,fontsize='xx-large');
pivot
# Out:
# Season  2000-2001  2001-2002  2002-2003  2003-2004  2004-2005  2005-2006  \
# Pos
# C              93         98        101         97        106        100
# PF             89         87         82         99         87         92
# PG            101         89         87         83         86         96
# SF             88         80         77         84         91         84
# SG             70         86         81         79         94         86
#
# Season  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  \
# Pos
# C              95        102         97         91        105        101
# PF            108         95         92         89         81         96
# PG             84         84         82         89         81         93
# SF             74         73         82         89         91         94
# SG             97         96         90         84         94         94
#
# Season  2012-2013  2013-2014  2014-2015  2015-2016  2016-2017  2017-2018  \
# ...

# %% [markdown]
# The grouped bar plot above aggregated with the seasons shows how each position has changed in count throughout time, this plot in particular helps show the changes throughout the seasons where the previous plot was more useful to view the positional distribution in each particular season. From this graph and the pivot table above we can see that the shooting guard position has a left skewed exponential distibution and has had an over all increase from the 2000-2001 season to the 2019-2020 season, whereas the small forward and center postions have relatively stayed the same (slightly uniform). The point guard and power forward positions have also had slight increases as shown with their left skewed exponential distibutions while the other positions appear more as slightly uniform distributions.

# %%
seasons = [str(i) + '-' + str(i+1) for i in range(2000, 2020)]

MP_df = pd.DataFrame()
for i in range(len(frames)):
    MP_df = MP_df.append((frames[i].groupby('Pos')['MP'].sum()).to_frame().assign(**{'Season': [seasons[i]]*5}).reset_index())

fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(axes=ax, x='Season', y='MP', hue='Pos', data=MP_df)
f = plt.xticks(rotation=30)
plt.suptitle("Minutes Played for Each Season (2000-2020)",y =.93,fontsize='xx-large');

# %% [markdown]
# Another statistic we looked at to measure this is the minutes played by position. Again, this line plot shows there isn't a very meaningful distribution in minutes played by position, although it is interesting to note that shooting guards are the most playing position currently.

# %%
r, c = 5, 4
fig, axes = plt.subplots(r, c, figsize=(25, 25))

seasons = [str(i) + '-' + str(i+1) for i in range(2000, 2020)]

i = 0
for x in range(r):
    for y in range(c):
        sns.histplot(ax=axes[x, y], x='3PA', data=frames[i], stat='density', bins=20)
        axes[x, y].set_ylim([0, .02])
        axes[x, y].set_xlim([0, 900])
        axes[x, y].set_title(f'3PA for {seasons[i]} Season')
        i += 1
        
plt.show()

# %% [markdown]
# This histogram displays the density of 3 point attempts for all players for each season. It appears that in later seasons the right tail of the distribution increases in volume and length, for example in the 2000-2001 season the density drops off quicker as 3PA increases compared to the 2018-2019 season. We also notice that in the later seasons there are more players attempting over 600 3 pointers in a season and that the density of players attempting very few 3 pointers has decreased significantly.

# %%
r, c = 5, 4
fig, axes = plt.subplots(r, c, figsize=(25, 25))

seasons = [str(i) + '-' + str(i+1) for i in range(2000, 2020)]

i = 0
for x in range(r):
    for y in range(c):
        sns.histplot(ax=axes[x, y], x='2PA', data=frames[i], stat='density', bins=20)
        axes[x, y].set_ylim([0, .006])
        axes[x, y].set_xlim([0, 1700])
        axes[x, y].set_title(f'2PA for {seasons[i]} Season')
        i += 1
        
plt.show()

# %% [markdown]
# This histogram displays the density of 2 point attempts for all players for each season. It appears that the right tail of the distribution doesn't have any noticable or predicatble changes from season to season. However, unlike the distribution for 3 point attempts we see that as the seasons progress there are more players taking very few 2 point attempts. This might be attributed to the emergence of role players that are mainly utilized for 3 point shooting rather than general purpose scoring.

# %%
tmp = agg_df.groupby(["Season","Pos"]).mean()['3PA'].reset_index()
pvt = tmp.pivot("Season", "Pos", '3PA')
plt.figure(figsize = (14,6))
sns.lineplot(data=pvt);
plt.xticks(rotation=45);
plt.suptitle("Average 3 Point Attempts by Position Over Time (2000-2020 seasons)", y =.93, fontsize='xx-large');
plt.xlabel("Season")
plt.ylabel("Average 3 Point Attempts");

# %% [markdown]
# This line plot displays the count of 3 point attempts per position in each season. Each line represents a different position and we can see a clear positive trend in each position throughout the seasons. For smaller players such as PG / SG we see a smaller increase in average 3 point attempts and for slightly bigger players such as SF we see a moderate increase in average 3 point attempts. We see the greatest increase in the physically bigger players such as PF / C where the average 3PA have increased greatly in the past 5 years. The greater 3PA for big men might be attributed to the greater demand for 3 point shooting in the modern era.

# %%
tmp = (agg_df.groupby(["Season","Pos"]).mean()['3PA']/agg_df.groupby(["Season","Pos"]).mean()['FGA']).reset_index().rename(columns={0:'Three_PA_perc'})
pvt = tmp.pivot("Season", "Pos", 'Three_PA_perc')
plt.figure(figsize = (14,6))
sns.lineplot(data=pvt);
plt.xticks(rotation=45);
plt.suptitle("Average 3 Point Attempts Percentage by Position Over Time (2000-2020 seasons)", y =.93, fontsize='xx-large');
plt.xlabel("Season")
plt.ylabel("Average 3 Point Attempts Percentage");

# %% [markdown]
# The first grouped plot prior to this one, we can se there are quite a few sharp dips and increases due to various external factors such as the lockout in 2011-2012 and the start of the pandemic in 2019-2020. To more clearly analyze trends over the various variables and observations we decided to instead use the average of 3 point attempts per position as a proportion of their total field goal attempts in each season, which we will refer to as 3 point attempt percentage. Each line represents a different position and we can see a clear positive trend in each position throughout the seasons. For smaller players such as PG / SG/ SF we see a smaller increase in 3 point attempt percentage and we see a larger increase in the physically bigger players such as PF / C where the 3 point attempt percentage has increased greatly in the past 5 years. The greater 3 point attempt percentage for big men might be attributed to the greater demand for 3 point shooting in the modern era.

# %%
tmp = (agg_df.groupby(["Season","Pos"]).mean()['2PA']/agg_df.groupby(["Season","Pos"]).mean()['FGA']).reset_index().rename(columns={0:'Two_PA_perc'})
pvt = tmp.pivot("Season", "Pos", 'Two_PA_perc')
plt.figure(figsize = (14,6))
sns.lineplot(data=pvt);
plt.xticks(rotation=45);
plt.suptitle("Average 2 Point Attempts Precentage by Position Over Time (2000-2020 seasons)", y =.93, fontsize='xx-large');
plt.xlabel("Season")
plt.ylabel("Average 2 Point Attempts Precentage");

# %% [markdown]
# This line plot displays the Proportion of 2 point attempts per position as a proportion of their total field goal in each season. Contrary to the average three point attempts, the average two point attempts has decreased. Since players are taking more attempts at the three point shots, it is natural that we see the average two point attempts go down. It is important to note that the 2011-2012 season was shortened to 66 games due to the NBA lockout and the 2019-2020 season varied from 65 to 75 due to a shortened season caused by COVID-19. As a result, those years experienced lower numbers.

# %%
tmp = agg_df.groupby(["Season","Pos"]).mean()['FGA'].reset_index()
pvt = tmp.pivot("Season", "Pos", 'FGA')
plt.figure(figsize = (14,6))
sns.lineplot(data=pvt);
plt.xticks(rotation=45);
plt.suptitle("Average Total Field Goal Attempts by Position Over Time (2000-2020 seasons)", y =.93, fontsize='xx-large');
plt.xlabel("Season")
plt.ylabel("Average Total Field Goal Point Attempts");

# %% [markdown]
# The average total field goal attempts has decreased over time for the small forward, shooting guard, and power forward positions. For the center and point guard positions, the average total field goal attempts have gradually increased, however, we do see a sharp decrease in the FGA for center position in the last season. It is important to note that the 2011-2012 season was shortened to 66 games due to the NBA lockout and the 2019-2020 season varied from 65 to 75 due to a shortened season caused by COVID-19. As a result, those years experienced lower numbers.

# %%
plt.figure(figsize = (13,6))
sns.boxplot(x="Pos", y="3PA", data=agg_df).set_title("Box Plot for 3 Point Attempts by Position");

# %% [markdown]
# This boxplot portrays the distribution of three point field goal attempts by position. There is a vast difference among positions here as centers (C) rarely shoot three pointers. Meanwhile, shooting guards (SG) shoot the highest amount of three pointers. There are many outliers on the upper ends of the distributions, particularly among centers, power forwards, and point guards.

# %%
plt.figure(figsize = (13,6))
sns.boxplot(x="Pos", y="2PA", data=agg_df).set_title("Box Plot for 2 Point Attempts by Position");

# %% [markdown]
# This boxplot portrays the distribution of two point field goal attempts by position. The data is skewed right (many bench players do not get as much playing time). There are many outliers on the higher end of the distribution for each position. The data for all positions is relatively similar (esp the medians). The power forward (PF) position has a notably high range compared to the other positons.

# %%
plt.figure(figsize = (14,6))
plt.xticks(rotation=45);
sns.boxplot(x="Season", y="3PA", data=agg_df).set_title("Box Plot for 3 Point Attempts by Season");

# %% [markdown]
# This boxplot portrays each player's total number of three point field goal attempts by season. We can see that the data is skewed right and there are considerable outliers on the higher end of the values. It is important to note that the 2011-2012 season was shortened to 66 games due to the NBA lockout and the 2019-2020 season varied from 65 to 75 due to a shortened season caused by COVID-19.

# %%
plt.figure(figsize = (14,6))
plt.xticks(rotation=45);
sns.boxplot(x="Season", y="2PA", data=agg_df).set_title("Box Plot for 2 Point Attempts by Season");

# %% [markdown]
# This boxplot portrays each player's total number of two point field goal attempts by season. We can see that the data is skewed right and there are considerable outliers on the higher end of the values. It is important to note that the 2011-2012 season was shortened to 66 games due to the NBA lockout and the 2019-2020 season varied from 65 to 75 due to a shortened season caused by COVID-19.

# %%
seasons = agg_df.Season.unique().tolist()
three_pa_szn = pd.Series(dict(zip(seasons, [frames[i]['3PA'].sum() for i in range(len(frames))])))

def helper(x):
    return pd.DataFrame(x)[0].apply(lambda x: int(x[:4])).to_frame()

pl_3pa = Pipeline([
    ('ft', FunctionTransformer(helper)),
    ('lr', LinearRegression())
])

pl_3pa.fit(three_pa_szn.index, three_pa_szn.values)
preds = pl_3pa.predict(three_pa_szn.index.to_numpy().reshape(-1, 1))

fig, ax = plt.subplots(figsize=(14, 5))
dots = sns.scatterplot(axes=ax, data=three_pa_szn)
line = sns.lineplot(axes=ax, data=preds, color='red')
f = plt.xticks(rotation=30)
f = ax.set(title='Total 3PA per Season', xlabel='Season', ylabel='Total 3PA')

# %% [markdown]
# This scatter plot displays the total 3 point attempts for all players in each season. We generated a ordinary least squares linear regression line to visualize the trend of 3PA throughout the seasons. One potential problem with this visualization is the fact that total 3PA can be affected by confounding factors. For example we can see that there are outliers in the scatterplot for the 2011-2012 season and the 2019-2020 season. In 2011-2012 the NBA lockout shut down all NBA related games / practices / etc. for part of the season, which in effect shortened the season and lowered the total shot attempts. Similarly in 2019-2020 the NBA had strict COVID restrictions and a shortened season, some players did not participate in the season which again affected total shot attempts for the season.

# %%
pct_total_fga = pd.Series(dict(zip(seasons, [frames[i]['3PA'].sum() / (frames[i]['3PA'].sum() + frames[i]['2PA'].sum()) for i in range(len(frames))])))

def helper(x):
    return pd.DataFrame(x)[0].apply(lambda x: int(x[:4])).to_frame()

pl_3_prop = Pipeline([
    ('ft', FunctionTransformer(helper)),
    ('lr', LinearRegression())
])

pl_3_prop.fit(pct_total_fga.index, pct_total_fga.values)
preds = pl_3_prop.predict(pct_total_fga.index.to_numpy().reshape(-1, 1))
preds

fig, ax = plt.subplots(figsize=(14, 5))
dots = sns.scatterplot(axes=ax, data=pct_total_fga)
dots.set_xlabel('Season')
dots.set_xlabel('Total 3PA')
line = sns.lineplot(axes=ax, data=preds, color='red')
f = plt.xticks(rotation=30)
f = ax.set(title='3 Pointers as a Proportion of All FGA per Season', xlabel='Season', ylabel='Proportion')

# %% [markdown]
# This scatter plot displays the proportion of 3 point attempts in relation to all field goal attempts for all players in each season. We generated a ordinary least squares linear regression line to visualize the trend of 3 pointers throughout the seasons. This visualization is a clearer representation of how often 3 pointers are being attempted in relation to all shots in a season. We can see a clear trend in this scatter plot as later seasons have more 3 point attempts relative to all field goal attempts.

# %%
# Predicts 3pa for a given input year, input must be string!
def predict_3pa(x):
    b = pl_3_prop.named_steps['lr'].intercept_
    m = pl_3_prop.named_steps['lr'].coef_[0]
    pred = (m*int(x)) + b
    if pred > 1:
        return 1
    elif pred < 0:
        return 0
    else:
        return pred
    return 

predict_3pa('2022')
# Out:
# 0.36801991843849535

# %% [markdown]
# Using the model built above we can naively predict future 3 point attempts assuming that the trend observed thus far continues. However we believe that this model can be greatly improved upon because as it stands this model relates year / season with 3 point proportion linearly, because of this property unreasonably high proportions may be predicted with very large input years. We believe that a more complex model that follows a s-curve with an unknown asymptote < 1 would model the increase in 3 point proportion better as it is extremely unlikely that 3 pointers will ever be taken more than 2 pointers due to factors such as higher difficulty for 3 pointers and evolving defenses.

# %%
# train-test 70-30 split
df_train, df_test = train_test_split(agg_df, 
                                     train_size = 0.7, 
                                     test_size = 0.3)

pct_total_fga_train = (df_train.groupby('Season')['3PA'].sum() / (df_train.groupby('Season')['3PA'].sum() + df_train.groupby('Season')['2PA'].sum()))
pct_total_fga_test = (df_test.groupby('Season')['3PA'].sum() / (df_test.groupby('Season')['3PA'].sum() + df_test.groupby('Season')['2PA'].sum()))

# divide into X_train, y_train, X_test, y_test
y_train = pct_total_fga_train.values
X_train = np.array([int(x[:4]) for x in pct_total_fga_train.index.tolist()]).reshape(-1, 1)

y_test = pct_total_fga_test.values
X_test = np.array([int(x[:4]) for x in pct_total_fga_test.index.tolist()]).reshape(-1, 1)

lm = LinearRegression()
lm.fit(X_train, y_train)
preds = lm.predict(X_test)

# evaluate the model on test set
r2 = sklearn.metrics.r2_score(y_test, preds)
print(f'Predictions: {preds}\n')
print(f'r^2: {r2}')
# Out:
# Predictions: [0.1510303  0.16094911 0.17086792 0.18078672 0.19070553 0.20062433
#  0.21054314 0.22046195 0.23038075 0.24029956 0.25021836 0.26013717
#  0.27005598 0.27997478 0.28989359 0.29981239 0.3097312  0.31965001
#  0.32956881 0.33948762]
#
# r^2: 0.774571810391212

# %% [markdown]
# In the code block above we implement train test split from sklearn in order to evaluate the accuracy of our model on untrained data, our observed r^2 is ~ 0.8

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

folds = KFold(n_splits = 5, shuffle = True)
scores = cross_val_score(lm, X_train, y_train, scoring='r2', cv=folds)
scores
# Out:
# array([0.68405908, 0.81086405, 0.79306156, 0.90441757, 0.92428462])

# %% [markdown]
# We performed KFold cross validation on our model with r^2 scores to see how generalizable our model would be when predicting on untrained data. It appears to perform well however there is a large amount of variance between scores.

# %%
# MSE
scores = cross_val_score(lm, X_train, y_train, scoring='neg_mean_squared_error', cv=folds)
-1*scores
# Out:
# array([4.20831552e-04, 6.75633492e-04, 3.16615442e-04, 5.43907148e-05,
#        1.02367753e-03])

# %% [markdown]
# Here we perform cross validation with mean squared error which suggests that our your regression model is quite accurate since these low error values tell us the distance of our prediction values are close to the true values in the sample.

# %%
total_2pa = pd.Series(dict(zip(seasons, [frames[i]['2PA'].sum() for i in range(len(frames))])))

def helper(x):
    return pd.DataFrame(x)[0].apply(lambda x: int(x[:4])).to_frame()

pl_2pa = Pipeline([
    ('ft', FunctionTransformer(helper)),
    ('lr', LinearRegression())
])

pl_2pa.fit(total_2pa.index, total_2pa.values)
preds = pl_2pa.predict(total_2pa.index.to_numpy().reshape(-1, 1))

fig, ax = plt.subplots(figsize=(14, 5))
dots = sns.scatterplot(axes=ax, data=total_2pa)
dots.set_xlabel('Season')
dots.set_xlabel('Total 2PA')
line = sns.lineplot(axes=ax, data=preds, color='red')
f = plt.xticks(rotation=30)
f = ax.set(title='2 Point Attempts per Season', xlabel='Season', ylabel='2 Point Attempts')

# %% [markdown]
# This scatter plot displays the total 2 point attempts for all players in each season. We generated an ordinary least squares linear regression line to visualize the trend of 2PA throughout the seasons. A potential problem with this visualization is that the total 2PA can be affected by confounding factors in similar way as to how the total 3PA my have been affected. For example the shortened seasons that we discussed about under the 3PA visualization.

# %%
pct_total_fga_2 = pd.Series(dict(zip(seasons, [frames[i]['2PA'].sum() / (frames[i]['3PA'].sum() + frames[i]['2PA'].sum()) for i in range(len(frames))])))

def helper(x):
    return pd.DataFrame(x)[0].apply(lambda x: int(x[:4])).to_frame()

pl_2_prop = Pipeline([
    ('ft', FunctionTransformer(helper)),
    ('lr', LinearRegression())
])

pl_2_prop.fit(pct_total_fga_2.index, pct_total_fga_2.values)
preds = pl_2_prop.predict(pct_total_fga_2.index.to_numpy().reshape(-1, 1))
preds

fig, ax = plt.subplots(figsize=(14, 5))
dots = sns.scatterplot(axes=ax, data=pct_total_fga_2)
dots.set_xlabel('Season')
dots.set_xlabel('Total 3PA')
line = sns.lineplot(axes=ax, data=preds, color='red')
f = plt.xticks(rotation=30)
f = ax.set(title='2 Pointers as a Proportion of All FGA per Season', xlabel='Season', ylabel='Proportion')

# %% [markdown]
# This scatter plot displays the proportion of 2 point attempts in relation to all field goal attempts for all players in each season. We generated an ordinary least squares linear regression line to visualize the trend of 2 pointers throughout the seasons. This visualization is a clearer representation of how often 2 pointers are being attempted in relation to all shots in a season. We can see a clear trend in this scatter plot as later seasons have less 2 point attempts relative to all field goal attempts.

# %%
# Predicts 2pa for a given input year, input must be string!
def predict_2pa(x):
    b = pl_2_prop.named_steps['lr'].intercept_
    m = pl_2_prop.named_steps['lr'].coef_[0]
    pred = (m*int(x)) + b
    if pred > 1:
        return 1
    elif pred < 0:
        return 0
    else:
        return pred
    return 

predict_2pa('2022')
# Out:
# 0.6319800815615046

# %% [markdown]
# Using the model built above we can naively predict future 2 point attempts assuming that the trend observed thus far continues. Similar to the 3pa model this model has the same problems as it is extremely unlikely that 2 pointers will ever be taken less than 3 pointers due to factors such as higher difficulty for 3 pointers and defenses adjusting for changing scoring methods.

# %%
from sklearn.model_selection import train_test_split
import sklearn

# train-test 70-30 split
df_train, df_test = train_test_split(agg_df, 
                                     train_size = 0.7, 
                                     test_size = 0.3)


pct_total_fga_train = (df_train.groupby('Season')['2PA'].sum() / (df_train.groupby('Season')['3PA'].sum() + df_train.groupby('Season')['2PA'].sum()) )
pct_total_fga_test = (df_test.groupby('Season')['2PA'].sum() / (df_test.groupby('Season')['3PA'].sum() + df_test.groupby('Season')['2PA'].sum()) )

# divide into X_train, y_train, X_test, y_test
y_train = pct_total_fga_train.values
X_train = np.array([int(x[:4]) for x in pct_total_fga_train.index.tolist()]).reshape(-1, 1)

y_test = pct_total_fga_test.values
X_test = np.array([int(x[:4]) for x in pct_total_fga_test.index.tolist()]).reshape(-1, 1)

lm = LinearRegression()
lm.fit(X_train, y_train)
preds = lm.predict(X_test)

# evaluate the model on test set
r2 = sklearn.metrics.r2_score(y_test, preds)
print(f'Predictions: {preds}\n')
print(f'r^2: {r2}')
# Out:
# Predictions: [0.84750473 0.83769187 0.82787902 0.81806616 0.8082533  0.79844045
#  0.78862759 0.77881474 0.76900188 0.75918903 0.74937617 0.73956332
#  0.72975046 0.71993761 0.71012475 0.7003119  0.69049904 0.68068618
#  0.67087333 0.66106047]
#
# r^2: 0.865424788226207

# %% [markdown]
# In the code block above we implement train test split from sklearn in order to evaluate the accuracy of our model on untrained data, our observed r^2 is ~ 0.8

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

folds = KFold(n_splits = 5, shuffle = True)
scores = cross_val_score(lm, X_train, y_train, scoring='r2', cv=folds)
scores
# Out:
# array([0.84767344, 0.85731735, 0.86865954, 0.85737417, 0.58251175])

# %% [markdown]
# We performed KFold cross validation with r^2 scores on our model to see how generalizable our model would be when predicting on untrained data.It appears to perform well however there is a large amount of variance between scores.

# %%
#MSE
scores = cross_val_score(lm, X_train, y_train, scoring='neg_mean_squared_error', cv=folds)
-1*scores
# Out:
# array([0.00127157, 0.00057759, 0.00028563, 0.00055374, 0.00059108])

# %% [markdown]
# Here we perform cross validation with mean squared error which suggests that our your regression model is quite accurate since these low error values tell us the distance of our prediction values are close to the true values in the sample.

# %%
df = pd.DataFrame(agg_df.groupby('Season')['3PA'].sum() / (agg_df.groupby('Season')['3PA'].sum() + agg_df.groupby('Season')['2PA'].sum())).reset_index().rename(columns = {'index':'Season', 0:'Three_PA'})
df['Season'] = df.Season.apply(lambda x: int(x[:4]))

# %%
#res = sm.OLS(df['Three_PA'], sm.add_constant(df.index)).fit()
df['centered_Season'] = df['Season'].apply(lambda x: x - df['Season'].mean())
outcome_1_2, predictors_1_2 = patsy.dmatrices('Three_PA ~ centered_Season', df)
mod_1_2 = sm.OLS(outcome_1_2, predictors_1_2)
res_2 = mod_1_2.fit()
print(res_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Three_PA   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     139.0
# Date:                Fri, 10 Dec 2021   Prob (F-statistic):           6.69e-10
# Time:                        15:54:27   Log-Likelihood:                 49.433
# No. Observations:                  20   AIC:                            -94.87
# Df Residuals:                      18   BIC:                            -92.87
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.2449      0.005     50.853      0.000       0.235       0.255
# ...

# %%
sns.regplot(x=df.index, y='Three_PA', data=df);

# %% [markdown]
# Above is the regression plot for the OLS model above.

# %% [markdown]
# The output above is the summary of our regression model, we can see that our model has a high r-squared of ~ 0.885 with a skew of 0.235 and kurtosis of 2.435.

# %%
sm.graphics.plot_fit(res_2, 'centered_Season');

# %% [markdown]
# This is a plot of our fitted values alongside our actual values, the bars show how far away our predictions are from the actual values.

# %%
model_norm_residuals = res_2.get_influence().resid_studentized_internal
fig = sns.scatterplot(x=res_2.fittedvalues, y=model_norm_residuals)
fig.set_xlabel('Fitted Values')
fig.set_ylabel("Standardized Residuals")
fig.set(title='Season Vs. Residuals')
fig.axhline(y=0, color='red', linestyle='dashed');

# %% [markdown]
# This plot shows the residuals of our linear regression, it appears that it does not fulfill the homoscedasticity requirement for linear regression

# %%
sns.boxplot(x=res_2.resid, showmeans=True);

# %% [markdown]
# This boxplot shows that our residuals are relatively normal, which we further investigate and confirm with the QQ plot below.

# %%
import scipy as sp
fig, ax = plt.subplots(figsize=(10,6))
_, (__, ___, r) = sp.stats.probplot(res_2.resid, plot=ax, fit=True)
r**2
# Out:
# 0.9740724143396109

# %% [markdown]
# We created a QQ plot to further visualize the normalcy of our data against a theoretical quantiles, which confirms that are data comes from a normal distribution.

# %%
#create instance of influence
influence = res_2.get_influence()

#obtain Cook's distance for each observation
cooks = influence.cooks_distance

plt.figure(figsize = (14,6))
plt.scatter(df.Season, cooks[0])
plt.xlabel('X')
plt.ylabel('Cooks Distance')
plt.show()

# %% [markdown]
# This plot is of the cooks distance and shows the most influential outliers for our model which are respectively 2019, 2018, 2000, 2001, 2012, 2011, 2010. These observation have the most influence on the fitted response values, and we may not remove them since each season is important for analysis of trends over time.

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)


xp = polynomial_features.fit_transform(np.array(df.Three_PA).reshape(-1, 1))

ols = sm.OLS(df['Season'], sm.add_constant(xp)).fit()
print(ols.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Season   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     344.7
# Date:                Fri, 10 Dec 2021   Prob (F-statistic):           1.75e-14
# Time:                        15:54:28   Log-Likelihood:                -26.150
# No. Observations:                  20   AIC:                             58.30
# Df Residuals:                      17   BIC:                             61.29
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1952.9506      4.412    442.679      0.000    1943.643    1962.258
# ...

# %% [markdown]
# Here we attempt to re-fit our model to a degree 2 polynomial because our previous model didn't satisfy the requirements of linear regression. However the extremely high r^2 suggests that we may be overfitting our model to the data.

# %%
model_norm_residuals = ols.get_influence().resid_studentized_internal
fig = sns.scatterplot(x=ols.fittedvalues, y=model_norm_residuals)
fig.set_xlabel('Fitted Values')
fig.set_ylabel("Standardized Residuals")
fig.set(title='Season Vs. Residuals')
fig.axhline(y=0, color='red', linestyle='dashed');

# %% [markdown]
# This plot visualizes the new residuals from our updated model which appears to have more constant variance, however the previous problem of overfitting remains. Therefore in order to do a proper regression to analyze 3 point trends over time we would need to gather more data across more seasons in order to have a greater amount of data points which will address this issue of non-constant variability to properly conduct a regression for our analysis

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# &emsp;&emsp; When conducting this project it is important for us to consider and keep in mind all of the potential ethical concerns, privacy concerns, and potential implications associated with our question and analysis. Since the data we will be using is comprised of professional athletes who have agreed to  official contracts, the players have given informed consent to publicize their information such as physical metrics that include weight, height, and date of birth as well as performance statistics. Therefore, informed consent has been addressed in our project and there also isn't a need to anonymize the data since the players have agreed and provided consent to the data we are using via their professional contract and through the nature data which is broadcasted and publicized openly for anyone to see and record. Furthermore, players have the right to opt out at any time and stop their statistics from being recorded by dropping out of the league and terminating their contract through a $0 buyout. However this right to opt out at any time isn't completely granted and there may be some ethical concerns, since players cannot request a deletion of their data after dropping out of the league due to their data already being publicized and because of the legality of NBA contracts.
#
# &emsp;&emsp; Furthermore, concerns for data storage have already been addressed due to the fact that the data set is open to the public and is already consented to by the subjects of the data to be released and non-anonymized. However it is important for us to be mindful of the data sets we are using and to be careful of where we are obtaining our data from. This is because, professional basketball is broadcasted and is available for anyone to record statistics upon, therefore it is important for us to obtain our data directly from the NBA and other reputable affiliates that provide reliable and unbiased data sets that are free of errors, missingingness, and other potentially misleading aspects of the data. As a result, it is important for us in our analysis to take into account ethical considerations that correspond to ensuring the data is clean to avoid any errors or misinformation in our results, which can possibly occur if we do not properly clean our data by filtering out missing values that may result in inaccurate results and analysis. In addition, we will set aside preconceptions and personal biases to avoid any misinterpreted or misleading results through factors such as cognitive bias. This is an important concern that we will address in order to prevent having our analysis being based on personal beliefs or unintentional external influences and to instead follow what the data suggests. It is important to address the threat of these potential ethical concerns especially in the topic of sports where there are many strong personal beliefs and biases accompanying certain teams, players, or other aspects of the sport.
#
# &emsp;&emsp; Additionally, we will ensure that our report is clear and understandable to the reader and ensure that our analysis has ethical modeling, since we will use variables from the data set that are understandable metrics that do not have any confounding factors or spurious correlations which could result in inaccurate and misleading results. Also we will provide proper documentation of all of our analysis procedures, data, variables, and other details in order to make it clear how we are forming our results and model to others to avoid appearing as a black box and to ensure our credibility.
#
# &emsp;&emsp; These ethical concerns are important for us to address in order for us to establish an analysis that is reliable as well as ethically posed and executed. Addressing these concerns go hand in hand with our ethics regarding the potential deployment of our analysis and model, since we attain to provide an accurate answer to our question since and any misleading results can lead to further ethical concerns and implications if people are misled, disadvantaged, or unethically benefiting from our model.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# &emsp;&emsp; There is no significant change in amount of players per position over the last 20 years. Although some years have specific positions playing more than others, this can be attributed to injuries, random chance, team compositions and other intangibles. From our analysis, there is a clear positive trend in the amount of 3 pointers shot by all positions over the last 20 years. Centers still lag behind in 3 point attempts and 3 point attempt percentage, but positions like power forward have surged past point guards. All 4 other positions are fairly close in 3 point attempts and 3 point attempt percentage. Trends show that the increase in 3 point attempts has not stopped yet, and if anything, is only increasing even faster than before. After our inferential analysis we saw an opportunity to experiment with predicting future shot attempts in the NBA. We created a linear model to predict both 3pa and 2pa, however after further testing and analysis we found that our model violated the homoscedasticity requirement for linear regression. We then attempted to refit the model with a degree 2 polynomial however we found that this new model suffered from overfitting as it had an extremely high r^2 value and resulted in  and other potential numerical problems since we saw a large condition number which might indicate that this may violate the multicollinearity requirement for linear regression. Therefore in order to do a proper regression to analyze 3 point trends over time we would need to gather more data across more seasons in order to have a greater amount of data points which will address this issue of non-constant variability to properly conduct a regression for our analysis
#
# &emsp;&emsp; If we had more thorough, detailed data to work with, we would study the trends in shooting regions as well. While we saw that three point shot attempts continue to rise, we are unable to tell where this increase comes from on the floor. Knowing whether the increase in 3 point attempts comes from the short corner 3, the long 3 at the top, or somewhere else, would provide beneficial insight into changes in shooting trends. This would also tie into positional shooting patterns to see which positions shoot 3 point shots  from which regions. Due to gameplans and the general location on the court of each position, players of each position likely attempt a different number of 3 point from each region. Another potential idea that could be explored would be the modeling of 3 point attempts on a positional basis and seeing if different positions have different distributions or trends. This data and these new questions would add a new dimension to our project, allowing us to draw more precise conclusions on changes in overall shooting trends (not just 3 point shots vs 2 point shots).

# %% [markdown]
# # Team Contributions

# %% [markdown]
# Matin Ghaffari - Data cleaning, EDA (aggregate plots, lineplots, barcharts, boxplots), regression fairness evaluation, OLS regression analysis and visualizations, ehtics and privacy, video
# <br>
# James Lu - Data cleaning, code / explanations for eda and regression analysis, video
# <br>
# Alan Amirian- Background, Some EDA code/explanations, conclusion, video
# <br>
# Jorge Acevedo - Overview, EDA and exaplantions, Background, video
# <br>
# Rahil Shah - Conclusion, Background
